# %%
# !pip install requests
class TravelChatbot:
    def get_flight_info(self, source, destination, date):
        # Simulate fetching flight information using an API (print a message for demonstration)
        print(f"Fetching flight info for {source} to {destination} on {date}")

    def get_hotel_info(self, location, check_in, check_out):
        # Simulate fetching hotel information using an API (print a message for demonstration)

        print(f"Fetching hotel info in {location} from {check_in} to {check_out}")
        def display_hotel_timing():
          print("Hotel Timings:")
          print("Monday-Friday: 8:00 AM - 10:00 PM")
          print("Saturday-Sunday: 9:00 AM - 11:00 PM")
          print()
        def display_menu():
          print("Menu:")
          print("1. Breakfast - $10")
          print("2. Lunch - $15")
          print("3. Dinner - $20")
          print("4. Snacks - $8")
          print()
          def main():
            print("Welcome to Our Hotel!")
            print("=======================")
            display_hotel_timing()
            display_menu()

    choice = input("Enter the number of your choice (1-4): ")

    if choice == "1":
        print("You've selected Breakfast. Enjoy your meal!")
    elif choice == "2":
        print("You've selected Lunch. Bon appétit!")
    elif choice == "3":
        print("You've selected Dinner. Enjoy your dinner!")
    elif choice == "4":
        print("You've selected Snacks. Enjoy your snack!")
    else:
        print("Invalid choice. Please select a valid option.")

    def start(self):
        print("Hello! I'm your travel chatbot. How can I assist you today?")

        while True:
            user_input = input("You: ").lower()

            if "exit" in user_input:
                print("Goodbye! Have a great trip.")
                break
            elif "flight" in user_input:
                source = input("Enter source: ")
                destination = input("Enter destination: ")
                date = input("Enter date (YYYY-MM-DD): ")
                self.get_flight_info(source, destination, date)
            elif "hotel" in user_input:
                location = input("Enter location: ")
                check_in = input("Enter check-in date (YYYY-MM-DD): ")
                check_out = input("Enter check-out date (YYYY-MM-DD): ")
                self.get_hotel_info(location, check_in, check_out)
            else:
                print("I'm sorry, I didn't understand that. Could you please rephrase?")

if __name__ == "__main__":
    travel_bot = TravelChatbot()
    travel_bot.start()
# Out:
# ...
# You've selected Lunch. Bon appétit!
# Hello! I'm your travel chatbot. How can I assist you today?
# Fetching hotel info in chennai from 2023-08-25 to 2023-08-26
